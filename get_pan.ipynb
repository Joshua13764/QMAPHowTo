# %% [markdown]
# ## Import the required modules

# %%
import matplotlib.pyplot as plt
import polars as pl
from polars import Expr, LazyFrame, DataFrame
import numpy as np
from pathlib import Path
from typing import Any, Dict, Callable
from QMAP_tools.qmap_inspector import QMAPInspector
from tqdm import tqdm

# %%
# Not required but improved the default layout of plots
import scienceplots
plt.style.use('science')
plt.rcParams["figure.figsize"] = (3.5, 3.5 * ((5**0.5 - 1) / 2)) # 3.5
plt.rcParams["figure.dpi"] = 600
# %matplotlib inline

# %%
qm = QMAPInspector()
# Load the helper class which by default has the standard relative paths of the database files so should work out of the box
# in most cases, however if the data is stored else where just use the init kwargs to set the correct path

# %%
qm.full_db.filter(pl.col("i") == 1).collect()
# The full database contains all the data needed to make the agg_db and some. It is very important that you do not try load
# the full database into memory so when previewing a standard way is to just filter by pl.col("i") == 1 which restricts the
# database to 1 / 8192 of its full size and therefore can be fully loaded into memory. We are still able to do operations
# on this dataset as you will see later leveraging the LazyFrame.
# Out:
# shape: (49_152, 134)
# ┌─────┬──────┬──────┬──────────┬───┬───────────────┬───────────────┬───────────────┬───────────────┐
# │ i   ┆ j    ┆ face ┆ area     ┆ … ┆ g_00800mm_spc ┆ g_01600mm_spc ┆ g_03170mm_spc ┆ g_06310mm_spc │
# │ --- ┆ ---  ┆ ---  ┆ ---      ┆   ┆ _obj_0000n000 ┆ _obj_0000n000 ┆ _obj_0000n000 ┆ _obj_0000n000 │
# │ u32 ┆ u32  ┆ str  ┆ f32      ┆   ┆ 00_v…         ┆ 00_v…         ┆ 00_v…         ┆ 00_v…         │
# │     ┆      ┆      ┆          ┆   ┆ ---           ┆ ---           ┆ ---           ┆ ---           │
# │     ┆      ┆      ┆          ┆   ┆ u64           ┆ u64           ┆ u64           ┆ u64           │
# ╞═════╪══════╪══════╪══════════╪═══╪═══════════════╪═══════════════╪═══════════════╪═══════════════╡
# │ 1   ┆ 0    ┆ negx ┆ 0.000676 ┆ … ┆ null          ┆ 1085          ┆ null          ┆ 17219         │
# │ 1   ┆ 1    ┆ negx ┆ 0.000681 ┆ … ┆ null          ┆ 1085          ┆ null          ┆ 17219         │
# │ 1   ┆ 2    ┆ negx ┆ 0.000654 ┆ … ┆ null          ┆ 1085          ┆ null          ┆ 17219         │
# │ 1   ┆ 3    ┆ negx ┆ 0.000647 ┆ … ┆ null          ┆ 1085          ┆ null          ┆ 17219         │
# │ 1   ┆ 4    ┆ negx ┆ 0.000632 ┆ … ┆ null          ┆ 1085          ┆ null          ┆ 17219         │
# │ …   ┆ …    ┆ …    ┆ …        ┆ … ┆ …             ┆ …             ┆ …             ┆ …             │
# │ 1   ┆ 8187 ┆ posz ┆ 0.000642 ┆ … ┆ null          ┆ 1108          ┆ 4386          ┆ 16714         │
# │ 1   ┆ 8188 ┆ posz ┆ 0.000639 ┆ … ┆ null          ┆ 1108          ┆ 4386          ┆ 16714         │
# │ 1   ┆ 8189 ┆ posz ┆ 0.000661 ┆ … ┆ null          ┆ 1108          ┆ 4386          ┆ 16714         │
# │ 1   ┆ 8190 ┆ posz ┆ 0.00062  ┆ … ┆ null          ┆ 1108          ┆ 4386          ┆ 16714         │
# │ 1   ┆ 8191 ┆ posz ┆ 0.00052  ┆ … ┆ null          ┆ 1108          ┆ 4386          ┆ 16714         │
# └─────┴──────┴──────┴──────────┴───┴───────────────┴───────────────┴───────────────┴───────────────┘

# %%
from QMAP_tools.base_map_tools import BaseMapTools

export_folder = Path(".plots/panoramas")
export_folder.mkdir(parents=True, exist_ok=True)

for col in tqdm(qm.full_db.columns, desc="Rendering panoramas"):
    try:
        fig_export_path = export_folder / f"{col}.png"

        if fig_export_path.exists():
            continue

        pan: np.ndarray = BaseMapTools.extract_column_as_equirectangular(
            df = qm.full_db.with_columns(pl.col(col).cast(pl.Float64)),
            column_name=col,
            output_resolution=(2048, 1024)
        )

        # Plot using plt
        plt.figure(figsize=(16, 8))
        plt.imshow(pan)
        plt.colorbar(label = col)
        plt.legend()
        plt.tight_layout()
        plt.savefig(fig_export_path)
        plt.close()

    except:
        print(f"Could not create panorama for {col}")
# Out:
# c:\Users\Joshu\AppData\Local\Programs\Python\Python313\Lib\site-packages\tqdm_joblib\__init__.py:4: TqdmExperimentalWarning: Using `tqdm.autonotebook.tqdm` in notebook mode. Use `tqdm.tqdm` instead to force console mode (e.g. in jupyter console)
#   from tqdm.autonotebook import tqdm
# C:\Users\Joshu\AppData\Local\Temp\ipykernel_7848\2282266232.py:6: PerformanceWarning: Determining the column names of a LazyFrame requires resolving its schema, which is a potentially expensive operation. Use `LazyFrame.collect_schema().names()` to get the column names without this warning.
#   for col in tqdm(qm.full_db.columns, desc="Rendering panoramas"):
# Rendering panoramas:   0%|          | 0/134 [00:00<?, ?it/s]
# Could not create panorama for i
# Could not create panorama for j
# Could not create panorama for face
# C:\Users\Joshu\AppData\Local\Temp\ipykernel_7848\2282266232.py:23: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()
# Rendering panoramas:  13%|█▎        | 17/134 [02:19<15:01,  7.71s/it]
# Could not create panorama for TIR detailed_survey facet mesh
# Rendering panoramas:  19%|█▉        | 26/134 [03:52<14:22,  7.99s/it]
# Could not create panorama for TIR recona facet mesh
# Rendering panoramas:  26%|██▌       | 35/134 [05:24<13:33,  8.21s/it]
# Could not create panorama for TIR reconb facet mesh
# Rendering panoramas:  33%|███▎      | 44/134 [06:51<12:22,  8.25s/it]
# Could not create panorama for TIR reconc facet mesh
# Rendering panoramas:  42%|████▏     | 56/134 [08:33<10:46,  8.29s/it]
# Could not create panorama for VNIR detailed_survey facet mesh
# Rendering panoramas:  72%|███████▏  | 96/134 [14:10<04:37,  7.30s/it]
# Could not create panorama for VNIR reconc facet mesh
# Rendering panoramas:  76%|███████▌  | 102/134 [15:14<05:36, 10.52s/it]
# Could not create panorama for detection_lod_code
# Rendering panoramas: 100%|██████████| 134/134 [21:20<00:00,  9.56s/it]
