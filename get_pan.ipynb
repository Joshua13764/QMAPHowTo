# %% [markdown]
# ## Import the required modules

# %%
import matplotlib.pyplot as plt
import polars as pl
from polars import Expr, LazyFrame, DataFrame
import numpy as np
from pathlib import Path
from typing import Any, Dict, Callable
from QMAP_tools.qmap_inspector import QMAPInspector

# %%
# Not required but improved the default layout of plots
import scienceplots
plt.style.use('science')
plt.rcParams["figure.figsize"] = (3.5, 3.5 * ((5**0.5 - 1) / 2)) # 3.5
plt.rcParams["figure.dpi"] = 600
# %matplotlib inline

# %%
qm = QMAPInspector()
# Load the helper class which by default has the standard relative paths of the database files so should work out of the box
# in most cases, however if the data is stored else where just use the init kwargs to set the correct path

# %%
qm.full_db.filter(pl.col("i") == 1).collect()
# The full database contains all the data needed to make the agg_db and some. It is very important that you do not try load
# the full database into memory so when previewing a standard way is to just filter by pl.col("i") == 1 which restricts the
# database to 1 / 8192 of its full size and therefore can be fully loaded into memory. We are still able to do operations
# on this dataset as you will see later leveraging the LazyFrame.
# Out:
# shape: (49_152, 85)
# ┌─────┬──────┬──────┬──────────┬───┬───────────────┬───────────────┬───────────────┬───────────────┐
# │ i   ┆ j    ┆ face ┆ area     ┆ … ┆ TIR reconb    ┆ VNIR detailed ┆ VNIR recona   ┆ VNIR reconc   │
# │ --- ┆ ---  ┆ ---  ┆ ---      ┆   ┆ tri_num alpha ┆ _survey       ┆ tri_num alpha ┆ tri_num alpha │
# │ u32 ┆ u32  ┆ str  ┆ f32      ┆   ┆ ---           ┆ tri_num a…    ┆ ---           ┆ ---           │
# │     ┆      ┆      ┆          ┆   ┆ u32           ┆ ---           ┆ u32           ┆ u32           │
# │     ┆      ┆      ┆          ┆   ┆               ┆ u32           ┆               ┆               │
# ╞═════╪══════╪══════╪══════════╪═══╪═══════════════╪═══════════════╪═══════════════╪═══════════════╡
# │ 1   ┆ 2001 ┆ negx ┆ 0.001015 ┆ … ┆ 919           ┆ 4005          ┆ 919           ┆ 230           │
# │ 1   ┆ 2002 ┆ negx ┆ 0.001057 ┆ … ┆ 919           ┆ 4005          ┆ 919           ┆ 230           │
# │ 1   ┆ 2003 ┆ negx ┆ 0.001048 ┆ … ┆ 919           ┆ 4005          ┆ 919           ┆ 230           │
# │ 1   ┆ 2004 ┆ negx ┆ 0.000999 ┆ … ┆ 919           ┆ 4005          ┆ 919           ┆ 230           │
# │ 1   ┆ 1920 ┆ negx ┆ 0.000975 ┆ … ┆ 890           ┆ 3733          ┆ 890           ┆ 220           │
# │ …   ┆ …    ┆ …    ┆ …        ┆ … ┆ …             ┆ …             ┆ …             ┆ …             │
# │ 1   ┆ 7817 ┆ posz ┆ 0.000643 ┆ … ┆ 867           ┆ 5466          ┆ 867           ┆ 228           │
# │ 1   ┆ 7820 ┆ posz ┆ 0.00068  ┆ … ┆ 867           ┆ 5466          ┆ 867           ┆ 228           │
# │ 1   ┆ 7819 ┆ posz ┆ 0.00072  ┆ … ┆ 867           ┆ 5466          ┆ 867           ┆ 228           │
# │ 1   ┆ 7814 ┆ posz ┆ 0.000765 ┆ … ┆ 867           ┆ 5466          ┆ 867           ┆ 228           │
# │ 1   ┆ 7813 ┆ posz ┆ 0.000678 ┆ … ┆ 867           ┆ 5466          ┆ 867           ┆ 228           │
# └─────┴──────┴──────┴──────────┴───┴───────────────┴───────────────┴───────────────┴───────────────┘

# %%
from QMAP_tools.base_map_tools import BaseMapTools

export_folder = Path(".plots/panoramas")
export_folder.mkdir(parents=True, exist_ok=True)

for col in qm.full_db.filter(pl.col("i") == 1).collect().columns:
    try:
        fig_export_path = export_folder / f"panorama of {col}.png"
        if fig_export_path.exists():
            print(f"Skipped as panorama for {col} already exists")
            continue

        pan: np.ndarray = BaseMapTools.extract_column_as_equirectangular(
            df = qm.full_db.with_columns(pl.col(col).cast(pl.Float64)),
            column_name=col,
            output_resolution=(2048, 1024)
        )

        # Plot using plt
        plt.figure(figsize=(16, 8))
        plt.imshow(pan)
        plt.colorbar(label = col)
        plt.legend()
        plt.tight_layout()
        plt.savefig(fig_export_path)
        plt.close()

        print(f"Created panorama for {col}")
        
    except:
        print(f"Could not create panorama for {col}")
# Out:
# Could not create panorama for i
# Could not create panorama for j
# Could not create panorama for face
# Skipped as panorama for area already exists
# C:\Users\Joshu\AppData\Local\Temp\ipykernel_25500\2450789355.py:23: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()
# Created panorama for TIR detailed_survey tri_num
# Created panorama for TIR detailed_survey band depth 350
# Created panorama for TIR detailed_survey band depth 440
# Created panorama for TIR detailed_survey slope 1000
# Created panorama for TIR detailed_survey ratio 1000
# Created panorama for TIR detailed_survey sigma band depth 350
# Created panorama for TIR detailed_survey sigma band depth 440
# Created panorama for TIR detailed_survey sigma slope 1000
# Created panorama for TIR detailed_survey sigma ratio 1000
# Created panorama for TIR recona tri_num
# Created panorama for TIR recona band depth 350
# Created panorama for TIR recona band depth 440
# Created panorama for TIR recona slope 1000
# Created panorama for TIR recona ratio 1000
# Created panorama for TIR recona sigma band depth 350
# Created panorama for TIR recona sigma band depth 440
# Created panorama for TIR recona sigma slope 1000
# Created panorama for TIR recona sigma ratio 1000
# Created panorama for TIR reconb tri_num
# Created panorama for TIR reconb band depth 350
# Created panorama for TIR reconb band depth 440
# Created panorama for TIR reconb slope 1000
# Created panorama for TIR reconb ratio 1000
# Created panorama for TIR reconb sigma band depth 350
# Created panorama for TIR reconb sigma band depth 440
# Created panorama for TIR reconb sigma slope 1000
# Created panorama for TIR reconb sigma ratio 1000
# Created panorama for VNIR detailed_survey tri_num
# Created panorama for VNIR detailed_survey band depth
# Created panorama for VNIR detailed_survey reflectance
# Created panorama for VNIR detailed_survey slope1 poly
# Created panorama for VNIR detailed_survey slope2 poly
# Created panorama for VNIR detailed_survey sigma band depth
# Created panorama for VNIR detailed_survey sigma reflectance
# Created panorama for VNIR detailed_survey sigma slope1 poly
# Created panorama for VNIR detailed_survey sigma slope2 poly
# Created panorama for VNIR recona tri_num
# Created panorama for VNIR recona band depth
# Created panorama for VNIR recona reflectance
# Created panorama for VNIR recona slope1 poly
# Created panorama for VNIR recona slope2 poly
# Created panorama for VNIR recona sigma band depth
# Created panorama for VNIR recona sigma reflectance
# Created panorama for VNIR recona sigma slope1 poly
# Created panorama for VNIR recona sigma slope2 poly
# Created panorama for VNIR reconc tri_num
# Created panorama for VNIR reconc band depth
# Created panorama for VNIR reconc reflectance
# Created panorama for VNIR reconc slope1 poly
# Created panorama for VNIR reconc slope2 poly
# Created panorama for VNIR reconc sigma band depth
# Created panorama for VNIR reconc sigma reflectance
# Created panorama for VNIR reconc sigma slope1 poly
# Created panorama for VNIR reconc sigma slope2 poly
# Created panorama for uint8_reflectance
# Created panorama for 32bit_reflectance
# Created panorama for positions_x
# Created panorama for positions_y
# Created panorama for positions_z
# Created panorama for detection_lod_level
# Could not create panorama for detection_lod_code
# Created panorama for boulder_id
# Created panorama for Gamma
# Created panorama for Tau
# Skipped as panorama for Area already exists
# Created panorama for center_x
# Created panorama for min_x
