# %% [markdown]
# ## Import the required modules

# %%
import matplotlib.pyplot as plt
import polars as pl
from polars import Expr, LazyFrame, DataFrame
import numpy as np
from pathlib import Path
from typing import Any, Dict, Callable
from QMAP_tools.qmap_inspector import QMAPInspector
from tqdm import tqdm

# %%
# Not required but improved the default layout of plots
import scienceplots
plt.style.use('science')
plt.rcParams["figure.figsize"] = (3.5, 3.5 * ((5**0.5 - 1) / 2)) # 3.5
plt.rcParams["figure.dpi"] = 600
# %matplotlib inline

# %%
qm = QMAPInspector()
# Load the helper class which by default has the standard relative paths of the database files so should work out of the box
# in most cases, however if the data is stored else where just use the init kwargs to set the correct path

# %%
qm.full_db.filter(pl.col("i") == 1).collect()
# The full database contains all the data needed to make the agg_db and some. It is very important that you do not try load
# the full database into memory so when previewing a standard way is to just filter by pl.col("i") == 1 which restricts the
# database to 1 / 8192 of its full size and therefore can be fully loaded into memory. We are still able to do operations
# on this dataset as you will see later leveraging the LazyFrame.
# Out:
# shape: (49_152, 134)
# ┌─────┬──────┬──────┬──────────┬───┬───────────────┬───────────────┬───────────────┬───────────────┐
# │ i   ┆ j    ┆ face ┆ area     ┆ … ┆ g_00800mm_spc ┆ g_01600mm_spc ┆ g_03170mm_spc ┆ g_06310mm_spc │
# │ --- ┆ ---  ┆ ---  ┆ ---      ┆   ┆ _obj_0000n000 ┆ _obj_0000n000 ┆ _obj_0000n000 ┆ _obj_0000n000 │
# │ u32 ┆ u32  ┆ str  ┆ f32      ┆   ┆ 00_v…         ┆ 00_v…         ┆ 00_v…         ┆ 00_v…         │
# │     ┆      ┆      ┆          ┆   ┆ ---           ┆ ---           ┆ ---           ┆ ---           │
# │     ┆      ┆      ┆          ┆   ┆ u64           ┆ u64           ┆ u64           ┆ u64           │
# ╞═════╪══════╪══════╪══════════╪═══╪═══════════════╪═══════════════╪═══════════════╪═══════════════╡
# │ 1   ┆ 0    ┆ negx ┆ 0.000676 ┆ … ┆ null          ┆ 1085          ┆ null          ┆ 17219         │
# │ 1   ┆ 1    ┆ negx ┆ 0.000681 ┆ … ┆ null          ┆ 1085          ┆ null          ┆ 17219         │
# │ 1   ┆ 2    ┆ negx ┆ 0.000654 ┆ … ┆ null          ┆ 1085          ┆ null          ┆ 17219         │
# │ 1   ┆ 3    ┆ negx ┆ 0.000647 ┆ … ┆ null          ┆ 1085          ┆ null          ┆ 17219         │
# │ 1   ┆ 4    ┆ negx ┆ 0.000632 ┆ … ┆ null          ┆ 1085          ┆ null          ┆ 17219         │
# │ …   ┆ …    ┆ …    ┆ …        ┆ … ┆ …             ┆ …             ┆ …             ┆ …             │
# │ 1   ┆ 8187 ┆ posz ┆ 0.000642 ┆ … ┆ null          ┆ 1108          ┆ 4386          ┆ 16714         │
# │ 1   ┆ 8188 ┆ posz ┆ 0.000639 ┆ … ┆ null          ┆ 1108          ┆ 4386          ┆ 16714         │
# │ 1   ┆ 8189 ┆ posz ┆ 0.000661 ┆ … ┆ null          ┆ 1108          ┆ 4386          ┆ 16714         │
# │ 1   ┆ 8190 ┆ posz ┆ 0.00062  ┆ … ┆ null          ┆ 1108          ┆ 4386          ┆ 16714         │
# │ 1   ┆ 8191 ┆ posz ┆ 0.00052  ┆ … ┆ null          ┆ 1108          ┆ 4386          ┆ 16714         │
# └─────┴──────┴──────┴──────────┴───┴───────────────┴───────────────┴───────────────┴───────────────┘

# %% [markdown]
# ### Investigate detailed_survey data

# %%
ds_columns_of_interest: list[str] = [
    # Raw reflectance
    # "uint8_reflectance",
    "32bit_reflectance",

    # TIR spectral
    "TIR detailed_survey Slope1000",
    "TIR detailed_survey BD350",
    "TIR detailed_survey BD440",
    "TIR detailed_survey Ratio1000",

    "TIR detailed_survey sigma Slope1000",
    "TIR detailed_survey sigma BD350",
    "TIR detailed_survey sigma BD440",

    # VNIR spectral
    "VNIR detailed_survey BandArea3200to3600nm",
    "VNIR detailed_survey OH2700nm",
    "VNIR detailed_survey Pyroxene920nm",
    "VNIR detailed_survey Slope1polyfit",
    "VNIR detailed_survey Slope2polyfit",

    "VNIR detailed_survey sigma BandArea3200to3600nm",
    "VNIR detailed_survey sigma OH2700nm",
    "VNIR detailed_survey sigma Pyroxene920nm",
    "VNIR detailed_survey sigma Slope1polyfit",
    "VNIR detailed_survey sigma Slope2polyfit",
]

# %%
from itertools import product
from matplotlib import colors
reconc_columns_of_interest: list[str] = [
        column.replace("detailed_survey", "reconc")
        for column in ds_columns_of_interest
    ]

hist_2D_export_folder = Path(f".plots/reconc_detailed_survey_2d_hists")
hist_2D_export_folder.mkdir(exist_ok=True, parents=True)

for x_item, y_item in tqdm(
    {tuple(sorted(pair)) for pair in product(
        ds_columns_of_interest,
        reconc_columns_of_interest
        )},
    desc=f"Rendering 2D hists"
    ):
    
    try:
        export_path = hist_2D_export_folder / f"{x_item} vs {y_item}.png"
        if export_path.exists():
            continue

        filtered_lf = qm.full_db.filter(pl.col(x_item) != -9999.0, pl.col(y_item) != -9999.0)

        # Get the hist data
        counts, x_edges, y_edges = qm.get_column_hist2d(
            columns=(x_item, y_item),
            bin_ranges=(
                qm.get_column_extrema(x_item, filtered_lf), 
                qm.get_column_extrema(y_item, filtered_lf)
                ),
            bin_numbers=(100, 100),
            custom_lf=filtered_lf
        )

        plt.figure(figsize=(8, 6))

        plt.pcolormesh(
            x_edges,
            y_edges,
            counts.T,        # transpose because pcolormesh expects (y, x)
            shading="auto",
            cmap="RdYlGn_r",
            norm = colors.LogNorm()
        )

        plt.xlabel(x_item)
        plt.ylabel(y_item)
        plt.colorbar(label = r"Area ($m^2$)")
        plt.tight_layout()
        plt.savefig(export_path)
        plt.close()

    except:
        print(f"Failed for {x_item} vs {y_item}")
        continue
# Out:
# Rendering 2D hists:   0%|          | 1/324 [00:01<05:53,  1.09s/it]
# Failed for TIR detailed_survey BD350 vs TIR reconc Slope1000
# Rendering 2D hists:   1%|          | 2/324 [00:02<05:26,  1.01s/it]
# Failed for VNIR detailed_survey sigma Slope2polyfit vs VNIR reconc Slope1polyfit
# Rendering 2D hists:   3%|▎         | 11/324 [00:32<13:47,  2.65s/it]
# Failed for TIR detailed_survey sigma Slope1000 vs TIR reconc sigma Slope1000
# Rendering 2D hists:   7%|▋         | 22/324 [01:17<16:15,  3.23s/it]
# Failed for TIR reconc sigma Slope1000 vs VNIR detailed_survey sigma BandArea3200to3600nm
# Rendering 2D hists:   8%|▊         | 25/324 [01:27<16:05,  3.23s/it]
# Failed for TIR reconc Slope1000 vs VNIR detailed_survey Pyroxene920nm
# Rendering 2D hists:  11%|█         | 35/324 [02:04<12:39,  2.63s/it]
# Failed for VNIR detailed_survey Pyroxene920nm vs VNIR reconc Slope1polyfit
# Rendering 2D hists:  12%|█▏        | 39/324 [02:14<11:21,  2.39s/it]
# Failed for TIR reconc Slope1000 vs VNIR detailed_survey BandArea3200to3600nm
# Rendering 2D hists:  13%|█▎        | 42/324 [02:21<09:48,  2.09s/it]
# Failed for VNIR detailed_survey OH2700nm vs VNIR reconc sigma Slope1polyfit
# Rendering 2D hists:  15%|█▍        | 47/324 [02:37<13:46,  2.98s/it]
# Failed for 32bit_reflectance vs TIR reconc Slope1000
# Rendering 2D hists:  18%|█▊        | 59/324 [03:14<11:02,  2.50s/it]
# Failed for TIR detailed_survey sigma Slope1000 vs TIR reconc Slope1000
# Rendering 2D hists:  19%|█▉        | 62/324 [03:20<09:31,  2.18s/it]
# Failed for TIR detailed_survey Ratio1000 vs VNIR reconc Pyroxene920nm
# Rendering 2D hists:  20%|██        | 65/324 [03:29<10:56,  2.54s/it]
# Failed for VNIR detailed_survey sigma Slope1polyfit vs VNIR reconc sigma Slope1polyfit
# Rendering 2D hists:  21%|██▏       | 69/324 [03:42<11:09,  2.62s/it]
# Failed for VNIR detailed_survey sigma Pyroxene920nm vs VNIR reconc Slope1polyfit
# Rendering 2D hists:  22%|██▏       | 72/324 [03:53<12:26,  2.96s/it]
# Failed for TIR detailed_survey Ratio1000 vs TIR reconc BD350
# Rendering 2D hists:  24%|██▍       | 78/324 [04:17<14:40,  3.58s/it]
# Failed for TIR reconc Slope1000 vs VNIR detailed_survey sigma OH2700nm
# Rendering 2D hists:  26%|██▌       | 83/324 [04:33<11:51,  2.95s/it]
# Failed for VNIR detailed_survey sigma OH2700nm vs VNIR reconc sigma Slope1polyfit
# Rendering 2D hists:  29%|██▉       | 95/324 [05:14<10:50,  2.84s/it]
# Failed for TIR detailed_survey Ratio1000 vs VNIR reconc Slope2polyfit
# Rendering 2D hists:  31%|███▏      | 102/324 [05:44<12:16,  3.32s/it]
# Failed for TIR reconc Slope1000 vs VNIR detailed_survey Slope2polyfit
# Rendering 2D hists:  32%|███▏      | 104/324 [05:49<10:03,  2.74s/it]
# Failed for TIR detailed_survey Ratio1000 vs TIR reconc Ratio1000
# Rendering 2D hists:  34%|███▎      | 109/324 [06:07<11:13,  3.13s/it]
# Failed for VNIR detailed_survey OH2700nm vs VNIR reconc Slope1polyfit
# Rendering 2D hists:  35%|███▍      | 112/324 [06:16<10:23,  2.94s/it]
# Failed for TIR detailed_survey Ratio1000 vs TIR reconc sigma Slope1000
# Rendering 2D hists:  35%|███▌      | 114/324 [06:21<09:15,  2.65s/it]
# Failed for TIR detailed_survey Slope1000 vs TIR reconc Slope1000
# Rendering 2D hists:  35%|███▌      | 115/324 [06:23<08:00,  2.30s/it]
# Failed for VNIR detailed_survey Slope2polyfit vs VNIR reconc Slope1polyfit
# Rendering 2D hists:  38%|███▊      | 122/324 [06:48<10:31,  3.13s/it]
# Failed for VNIR detailed_survey BandArea3200to3600nm vs VNIR reconc sigma Slope1polyfit
# Rendering 2D hists:  38%|███▊      | 124/324 [06:54<09:54,  2.97s/it]
# Failed for TIR detailed_survey sigma BD350 vs VNIR reconc sigma Slope1polyfit
# Rendering 2D hists:  39%|███▉      | 127/324 [07:04<09:39,  2.94s/it]
# Failed for TIR detailed_survey Ratio1000 vs VNIR reconc sigma Pyroxene920nm
# Rendering 2D hists:  40%|███▉      | 128/324 [07:05<08:08,  2.49s/it]
# Failed for TIR reconc sigma Slope1000 vs VNIR detailed_survey Slope1polyfit
# Rendering 2D hists:  41%|████      | 132/324 [07:20<09:49,  3.07s/it]
# Failed for TIR detailed_survey BD350 vs VNIR reconc sigma Slope1polyfit
# Rendering 2D hists:  41%|████      | 133/324 [07:22<08:23,  2.63s/it]
# Failed for VNIR detailed_survey sigma Slope1polyfit vs VNIR reconc Slope1polyfit
# Rendering 2D hists:  42%|████▏     | 135/324 [07:28<08:28,  2.69s/it]
# Failed for TIR reconc sigma Slope1000 vs VNIR detailed_survey sigma Slope1polyfit
# Rendering 2D hists:  43%|████▎     | 140/324 [07:47<09:34,  3.12s/it]
# Failed for TIR detailed_survey Ratio1000 vs VNIR reconc Slope1polyfit
# Rendering 2D hists:  47%|████▋     | 151/324 [08:33<11:16,  3.91s/it]
# Failed for VNIR detailed_survey sigma OH2700nm vs VNIR reconc Slope1polyfit
# Rendering 2D hists:  48%|████▊     | 155/324 [08:47<09:13,  3.28s/it]
# Failed for VNIR detailed_survey Slope1polyfit vs VNIR reconc sigma Slope1polyfit
# Rendering 2D hists:  48%|████▊     | 156/324 [08:48<07:42,  2.75s/it]
# Failed for TIR reconc sigma Slope1000 vs VNIR detailed_survey sigma Slope2polyfit
# Rendering 2D hists:  49%|████▉     | 159/324 [09:00<09:07,  3.32s/it]
# Failed for TIR detailed_survey Ratio1000 vs TIR reconc Slope1000
# Rendering 2D hists:  52%|█████▏    | 167/324 [09:31<09:25,  3.60s/it]
# Failed for TIR reconc sigma Slope1000 vs VNIR detailed_survey sigma Pyroxene920nm
# Rendering 2D hists:  52%|█████▏    | 170/324 [09:54<15:08,  5.90s/it]
# Failed for 32bit_reflectance vs TIR detailed_survey Ratio1000
# Rendering 2D hists:  53%|█████▎    | 172/324 [10:01<11:20,  4.48s/it]
# Failed for 32bit_reflectance vs VNIR reconc sigma Slope1polyfit
# Rendering 2D hists:  53%|█████▎    | 173/324 [10:02<09:07,  3.63s/it]
# Failed for TIR reconc sigma Slope1000 vs VNIR detailed_survey OH2700nm
# Rendering 2D hists:  56%|█████▌    | 180/324 [10:36<11:39,  4.86s/it]
# Failed for TIR reconc Slope1000 vs VNIR detailed_survey sigma BandArea3200to3600nm
# Rendering 2D hists:  58%|█████▊    | 187/324 [11:06<08:17,  3.63s/it]
# Failed for VNIR detailed_survey Pyroxene920nm vs VNIR reconc sigma Slope1polyfit
# Rendering 2D hists:  58%|█████▊    | 188/324 [11:08<06:52,  3.03s/it]
# Failed for TIR reconc Slope1000 vs VNIR detailed_survey Slope1polyfit
# Rendering 2D hists:  58%|█████▊    | 189/324 [11:09<05:53,  2.62s/it]
# Failed for TIR detailed_survey sigma Slope1000 vs VNIR reconc sigma Slope1polyfit
# Rendering 2D hists:  59%|█████▊    | 190/324 [11:11<05:06,  2.28s/it]
# Failed for TIR reconc sigma Slope1000 vs VNIR detailed_survey Pyroxene920nm
# Rendering 2D hists:  60%|██████    | 196/324 [11:36<07:28,  3.50s/it]
# Failed for VNIR detailed_survey BandArea3200to3600nm vs VNIR reconc Slope1polyfit
# Rendering 2D hists:  61%|██████    | 197/324 [11:38<06:08,  2.90s/it]
# Failed for TIR detailed_survey Ratio1000 vs TIR reconc BD440
# Rendering 2D hists:  61%|██████    | 198/324 [11:39<05:14,  2.50s/it]
# Failed for TIR detailed_survey Ratio1000 vs TIR reconc sigma BD440
# Rendering 2D hists:  64%|██████▎   | 206/324 [12:14<07:30,  3.82s/it]
# Failed for TIR detailed_survey BD440 vs VNIR reconc sigma Slope1polyfit
# Rendering 2D hists:  66%|██████▌   | 213/324 [12:44<06:56,  3.76s/it]
# Failed for VNIR detailed_survey sigma BandArea3200to3600nm vs VNIR reconc sigma Slope1polyfit
# Rendering 2D hists:  68%|██████▊   | 221/324 [13:19<07:06,  4.15s/it]
# Failed for VNIR detailed_survey Slope1polyfit vs VNIR reconc Slope1polyfit
# Rendering 2D hists:  69%|██████▉   | 223/324 [13:25<05:34,  3.31s/it]
# Failed for TIR reconc Slope1000 vs VNIR detailed_survey OH2700nm
# Rendering 2D hists:  69%|██████▉   | 224/324 [13:26<04:39,  2.80s/it]
# Failed for TIR detailed_survey sigma BD440 vs VNIR reconc sigma Slope1polyfit
# Rendering 2D hists:  71%|███████   | 230/324 [13:48<05:02,  3.22s/it]
# Failed for TIR detailed_survey Ratio1000 vs VNIR reconc sigma Slope2polyfit
# Rendering 2D hists:  71%|███████▏  | 231/324 [13:50<04:25,  2.86s/it]
# Failed for 32bit_reflectance vs VNIR reconc Slope1polyfit
# Rendering 2D hists:  72%|███████▏  | 233/324 [13:55<04:06,  2.71s/it]
# Failed for TIR reconc sigma Slope1000 vs VNIR detailed_survey sigma OH2700nm
# Rendering 2D hists:  74%|███████▍  | 239/324 [14:18<04:34,  3.23s/it]
# Failed for TIR detailed_survey Slope1000 vs VNIR reconc sigma Slope1polyfit
# Rendering 2D hists:  75%|███████▍  | 242/324 [14:27<04:04,  2.99s/it]
# Failed for TIR detailed_survey BD440 vs TIR reconc sigma Slope1000
# Rendering 2D hists:  76%|███████▌  | 245/324 [14:37<04:07,  3.13s/it]
# Failed for TIR detailed_survey sigma Slope1000 vs VNIR reconc Slope1polyfit
# Rendering 2D hists:  77%|███████▋  | 248/324 [14:48<03:58,  3.13s/it]
# Failed for VNIR detailed_survey sigma Slope2polyfit vs VNIR reconc sigma Slope1polyfit
# Rendering 2D hists:  78%|███████▊  | 252/324 [15:02<03:57,  3.30s/it]
# Failed for TIR detailed_survey Ratio1000 vs VNIR reconc BandArea3200to3600nm
# Rendering 2D hists:  78%|███████▊  | 254/324 [15:09<03:39,  3.14s/it]
# Failed for TIR detailed_survey Ratio1000 vs VNIR reconc sigma BandArea3200to3600nm
# Rendering 2D hists:  81%|████████  | 261/324 [15:36<03:26,  3.28s/it]
# Failed for VNIR detailed_survey Slope2polyfit vs VNIR reconc sigma Slope1polyfit
# Rendering 2D hists:  81%|████████  | 263/324 [15:47<04:09,  4.09s/it]
# Failed for TIR reconc sigma Slope1000 vs VNIR detailed_survey Slope2polyfit
# Rendering 2D hists:  83%|████████▎ | 268/324 [16:06<03:23,  3.63s/it]
# Failed for TIR detailed_survey BD440 vs VNIR reconc Slope1polyfit
# Rendering 2D hists:  83%|████████▎ | 269/324 [16:08<02:56,  3.21s/it]
# Failed for TIR detailed_survey sigma BD350 vs TIR reconc sigma Slope1000
# Rendering 2D hists:  84%|████████▍ | 272/324 [16:21<03:08,  3.62s/it]
# Failed for TIR detailed_survey sigma BD440 vs TIR reconc sigma Slope1000
# Rendering 2D hists:  85%|████████▍ | 275/324 [16:30<02:24,  2.96s/it]
# Failed for TIR detailed_survey Ratio1000 vs VNIR reconc sigma OH2700nm
# Rendering 2D hists:  85%|████████▌ | 276/324 [16:31<02:02,  2.55s/it]
# Failed for TIR detailed_survey BD350 vs TIR reconc sigma Slope1000
# Rendering 2D hists:  87%|████████▋ | 281/324 [16:48<02:07,  2.97s/it]
# Failed for VNIR detailed_survey sigma BandArea3200to3600nm vs VNIR reconc Slope1polyfit
# Rendering 2D hists:  87%|████████▋ | 282/324 [16:50<01:43,  2.46s/it]
# Failed for TIR detailed_survey Ratio1000 vs VNIR reconc OH2700nm
# Rendering 2D hists:  88%|████████▊ | 284/324 [16:55<01:38,  2.46s/it]
# Failed for TIR detailed_survey Ratio1000 vs VNIR reconc sigma Slope1polyfit
# Rendering 2D hists:  89%|████████▊ | 287/324 [17:04<01:37,  2.63s/it]
# Failed for TIR detailed_survey Slope1000 vs TIR reconc sigma Slope1000
# Rendering 2D hists:  89%|████████▉ | 288/324 [17:05<01:21,  2.27s/it]
# Failed for TIR reconc Slope1000 vs VNIR detailed_survey sigma Slope1polyfit
# Rendering 2D hists:  90%|█████████ | 292/324 [17:19<01:33,  2.92s/it]
# Failed for TIR detailed_survey BD440 vs TIR reconc Slope1000
# Rendering 2D hists:  91%|█████████ | 295/324 [17:29<01:26,  2.97s/it]
# Failed for TIR detailed_survey sigma BD350 vs VNIR reconc Slope1polyfit
# Rendering 2D hists:  92%|█████████▏| 297/324 [17:34<01:13,  2.73s/it]
# Failed for TIR detailed_survey Ratio1000 vs TIR reconc sigma BD350
# Rendering 2D hists:  93%|█████████▎| 302/324 [17:52<01:08,  3.11s/it]
# Failed for TIR detailed_survey sigma BD440 vs VNIR reconc Slope1polyfit
# Rendering 2D hists:  94%|█████████▎| 303/324 [17:54<00:56,  2.70s/it]
# Failed for TIR reconc sigma Slope1000 vs VNIR detailed_survey BandArea3200to3600nm
# Rendering 2D hists:  94%|█████████▍| 305/324 [17:59<00:48,  2.57s/it]
# Failed for TIR detailed_survey BD350 vs VNIR reconc Slope1polyfit
# Rendering 2D hists:  96%|█████████▌| 311/324 [18:20<00:39,  3.04s/it]
# Failed for TIR detailed_survey Slope1000 vs VNIR reconc Slope1polyfit
# Rendering 2D hists:  97%|█████████▋| 313/324 [18:25<00:30,  2.76s/it]
# Failed for TIR reconc Slope1000 vs VNIR detailed_survey sigma Slope2polyfit
# Rendering 2D hists:  97%|█████████▋| 314/324 [18:27<00:24,  2.42s/it]
# Failed for 32bit_reflectance vs TIR reconc sigma Slope1000
# Rendering 2D hists:  97%|█████████▋| 315/324 [18:29<00:19,  2.21s/it]
# Failed for TIR detailed_survey sigma BD350 vs TIR reconc Slope1000
# Rendering 2D hists:  99%|█████████▉| 322/324 [18:54<00:06,  3.12s/it]
# Failed for VNIR detailed_survey sigma Pyroxene920nm vs VNIR reconc sigma Slope1polyfit
# Rendering 2D hists: 100%|█████████▉| 323/324 [18:56<00:02,  2.74s/it]
# Failed for TIR detailed_survey sigma BD440 vs TIR reconc Slope1000
# Rendering 2D hists: 100%|██████████| 324/324 [18:57<00:00,  3.51s/it]
# Failed for TIR reconc Slope1000 vs VNIR detailed_survey sigma Pyroxene920nm
